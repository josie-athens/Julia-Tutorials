# %% [raw]
# ---
# title: "Poisson Regression"
# author: Josie Athens
# date: today
# highlight-style: ayu
# format:
#   html:
#     code-fold: false
#     theme: mint
#     toc: true
#     number-sections: true
#     toc-title: Contents
#     smooth-scroll: true
#     embed-resources: true
# execute:
#   cache: true
#   warning: false
# ---

# %% [markdown]
# # [ 📖 Main Menu](index.html)

# %%
using StatsBase, DataFrames, DataFrameMacros
using RCall, CategoricalArrays, TexTables
using Distributions, Gadfly, Compose, MLJ
using GLM, Effects, MultipleTesting
import AnovaGLM as aov

using MLJ: schema

# %%
include("pubh.jl");
set_default_plot_size(15cm, 12cm)
@rlibrary readr
@rimport pubh

# %%
#| output: false
R"""
library(pubh)
library(sjlabelled)
""";
# Out:
# ┌ Warning: RCall.jl: Loading required package: emmeans
# │ Loading required package: ggformula
# │ Loading required package: ggplot2
# │ Loading required package: scales
# │ Loading required package: ggridges
# │
# │ New to ggformula?  Try the tutorials:
# │ 	learnr::run_tutorial("introduction", package = "ggformula")
# │ 	learnr::run_tutorial("refining", package = "ggformula")
# │ Loading required package: gtsummary
# │ Loading required package: huxtable
# │
# │ Attaching package: ‘huxtable’
# │
# │ The following object is masked from ‘package:gtsummary’:
# │
# │     as_flextable
# │
# │ The following object is masked from ‘package:scales’:
# │
# │     number_format
# │
# │ The following object is masked from ‘package:ggplot2’:
# │
# │     theme_grey
# │
# │ Loading required package: magrittr
# └ @ RCall ~/.julia/packages/RCall/dDAVd/src/io.jl:172
# ┌ Warning: RCall.jl:
# │ Attaching package: ‘sjlabelled’
# │
# │ The following object is masked from ‘package:huxtable’:
# │
# │     set_label
# │
# │ The following object is masked from ‘package:ggplot2’:
# │
# │     as_label
# │
# └ @ RCall ~/.julia/packages/RCall/dDAVd/src/io.jl:172

# %% [markdown]
# # Count Data

# %% [raw]
# ::: callout-tip
# ## Example
#
# We will use the data quine which is available from R. These data come from a sociological study of Australian aboriginal and white children. The sample included children from four age groups (final year in primary school and first three years in secondary school who were classified as slow or average learners. The number of days absent from school during the school year was recorded for each child.
# :::

# %%
quine = rcopy(R"MASS::quine")
quine |> schema
# Out:
# ┌───────┬───────────────┬──────────────────────────────────┐
# │ names │ scitypes      │ types                            │
# ├───────┼───────────────┼──────────────────────────────────┤
# │ Eth   │ Multiclass{2} │ CategoricalValue{String, UInt32} │
# │ Sex   │ Multiclass{2} │ CategoricalValue{String, UInt32} │
# │ Age   │ Multiclass{4} │ CategoricalValue{String, UInt32} │
# │ Lrn   │ Multiclass{2} │ CategoricalValue{String, UInt32} │
# │ Days  │ Count         │ Int64                            │
# └───────┴───────────────┴──────────────────────────────────┘

# %% [markdown]
# We change the name of the factors for `Eth` to Aboriginal and White and the `Sex` ones to Male and Female.

# %%
levels(quine.Eth)
# Out:
# 2-element Vector{String}:
#  "A"
#  "N"

# %%
quine.Eth = recode(
  quine.Eth,
  "A" => "Aboriginal" ,
  "N" => "White"
)

quine.Sex = recode(
  quine.Sex,
  "M" => "Male",
  "F" => "Female"
);

# %%
#| output: asis
R"""
quine = $quine |>
  var_labels(
    Days = "Number of absent days",
    Eth = "Ethnicity",
    Age = "Age group",
    Lrn = "Learner status"
)

quine |> 
  cross_tbl(by = "Eth") |> 
  theme_pubh(2) |>
  set_caption("Descriptve statistics by ethnicty.") |> 
  add_footnote("n (%); Median (IQR)", font_size = 9) |>
  print_html()
""";
# Out:
# <table class="huxtable" data-quarto-disable-processing="true" style="border-collapse: collapse; border: 0px; margin-bottom: 2em; margin-top: 2em; ; margin-left: auto; margin-right: auto;  ">
# <caption style="caption-side: top; text-align: center;">Descriptve statistics by ethnicty.</caption><col><col><col><col><tr>
# <th style="vertical-align: top; text-align: center; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;"></th><th colspan="2" style="vertical-align: top; text-align: center; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;"><p><strong>Ethnicity</strong></p>
# </th><th style="vertical-align: top; text-align: center; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;"></th></tr>
# <tr>
# <th style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;"></th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;"><p><strong>Aboriginal</strong>, N = 69</p>
# </th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;"><p><strong>White</strong>, N = 77</p>
# </th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;"><p><strong>Overall</strong>, N = 146</p>
# </th></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;">Sex</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;"></td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal;">Male</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">31 (45%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">35 (45%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">66 (45%)</td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal;">Female</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">38 (55%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">42 (55%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">80 (55%)</td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;">Age group</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;"></td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal;">F0</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">13 (19%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">14 (18%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">27 (18%)</td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal;">F1</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">20 (29%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">26 (34%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">46 (32%)</td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal;">F2</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">20 (29%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">20 (26%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">40 (27%)</td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal;">F3</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">16 (23%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">17 (22%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">33 (23%)</td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;">Learner status</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;"></td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal;">AL</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">40 (58%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">43 (56%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">83 (57%)</td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal;">SL</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">29 (42%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">34 (44%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">63 (43%)</td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.8pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold;">Number of absent days</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.8pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">15 (6, 32)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.8pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">7 (4, 16)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.8pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal;">11 (5, 23)</td></tr>
# <tr>
# <td colspan="4" style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0.8pt 0pt 0pt 0pt;    padding: 6pt 6pt 6pt 6pt; font-weight: normal; font-size: 9pt;">n (%); Median (IQR)</td></tr>
# </table>

# %% [markdown]
# We start by an intercept only model:

# %%
model_0 = glm(@formula(Days ~ 1), quine, Poisson())
glm_coef(model_0 |> coeftable |> DataFrame)
# Out:
# 1×5 DataFrame
#  Row │ Name         Coef.    Lower 95%  Upper 95%  Pr(>|z|)
#      │ String       Float64  Float64    Float64    Float64
# ─────┼──────────────────────────────────────────────────────
#    1 │ (Intercept)   16.459     15.814      17.13       0.0

# %% [raw]
# ::: callout-warning
# ## Question
#
# What does the coefficient in the above Poisson regression model represent?
# :::

# %% [raw]
# ::: callout-note
# ## Answer
#
# Represents the mean number of absent days. Thus, the mean number of absent days, regardless of ethnicity is 16.46 days (95% CI: 14.02, 19.33 days).
# :::

# %% [markdown]
# ## Univariate model
#
# Model estimating the effect of ethnicity:

# %%
levels!(quine.Eth, ["White", "Aboriginal"]);

# %%
model_1 = glm(@formula(Days ~ Eth), quine, Poisson())
glm_coef(model_1 |> coeftable |> DataFrame)
# Out:
# 2×5 DataFrame
#  Row │ Name             Coef.    Lower 95%  Upper 95%  Pr(>|z|)
#      │ String           Float64  Float64    Float64    Float64
# ─────┼──────────────────────────────────────────────────────────
#    1 │ (Intercept)       12.182     11.427     12.987       0.0
#    2 │ Eth: Aboriginal    1.743      1.606      1.892       0.0

# %% [raw]
# ::: callout-warning
# ## Question
#
# How would you interpret the output?
# :::

# %% [raw]
# ::: callout-note
# ## Answer
#
# On average, white students miss about 12 days per scholar year. Students from aboriginal origin miss about 74% more number of days per school-year (IRR = 1.74 absences/school-year, 95% CIs 1.61, 1.89; p < 0.001).
# :::

# %% [markdown]
# ## Multivariate analysis
#
# The potential confounders that we want to control for in this analysis are sex, age group and type of learner.

# %%
model_2 = glm(@formula(Days ~ Eth + Sex + Age + Lrn), quine, Poisson())
aov.anova(model_2, type=3)
# Out:
# Analysis of Variance
#
# Type 3 test / Likelihood-ratio test
#
# Days ~ 1 + Eth + Sex + Age + Lrn
#
# Table:
# ───────────────────────────────────────────────
#              DOF  Deviance        χ²  Pr(>|χ²|)
# ───────────────────────────────────────────────
# (Intercept)    1   2092.08  980.0371     <1e-99
# Eth            1   1925.24  166.8448     <1e-37
# Sex            1   1910.83   14.4053     0.0001
# Age            3   1742.50  168.3256     <1e-35
# Lrn            1   1696.71   45.7980     <1e-10
# ───────────────────────────────────────────────

# %%
glm_coef(model_2 |> coeftable |> DataFrame)
# Out:
# 7×5 DataFrame
#  Row │ Name             Coef.    Lower 95%  Upper 95%  Pr(>|z|)
#      │ String           Float64  Float64    Float64    Float64
# ─────┼──────────────────────────────────────────────────────────
#    1 │ (Intercept)       10.416      9.254     11.725       0.0
#    2 │ Eth: Aboriginal    1.705      1.571      1.851       0.0
#    3 │ Sex: Female        0.851      0.783      0.925       0.0
#    4 │ Age: F1            0.716      0.624      0.822       0.0
#    5 │ Age: F2            1.294      1.145      1.463       0.0
#    6 │ Age: F3            1.534      1.343      1.751       0.0
#    7 │ Lrn: SL            1.418      1.28       1.57        0.0

# %% [markdown]
# ## Goodness of fit
#
# When we use the Poisson distribution, we assume that the mean is equal to the variance. In other words, the residual deviance should be equal to the residual degrees of freedom. You obtain the corresponding values as part of the summary of the model. When this is not the case, we have overdispersion in our model.
#
# We can check for overdispersion:

# %%
deviance(model_2) / dof_residual(model_2) |> r3
# Out:
# 12.119

# %% [raw]
# ::: callout-warning
# ## Question
#
# What is your conclusion?
# :::

# %% [raw]
# ::: callout-note
# ## Answer
#
# There is overdispersion. The model does not properly fit the data.
# :::

# %% [markdown]
# ## Negative Binomial models
#
# When we have overdispersion, we have the alternative to scale the standard errors by using a Quasi-Poisson distribution or by using a Negative Binomial Distribution of the error.

# %%
model_nb = glm(
  @formula(Days ~ Eth + Sex + Age + Lrn), 
  quine, NegativeBinomial(2.0),
  LogLink()
);

# %%
aov.anova(model_nb, type=3)
# Out:
# Analysis of Variance
#
# Type 3 test / F test
#
# Days ~ 1 + Eth + Sex + Age + Lrn
#
# Table:
# ──────────────────────────────────────────────────────────
#              DOF  ΔDeviance  Mean ΔDev   F value  Pr(>|F|)
# ──────────────────────────────────────────────────────────
# (Intercept)    1   257.72     257.72    173.7053    <1e-25
# Eth            1    19.56      19.56     13.1808    0.0004
# Sex            1     0.4216     0.4216    0.2842    0.5948
# Age            3    17.97       5.9910    4.0379    0.0087
# Lrn            1     3.8783     3.8783    2.6139    0.1082
# (Residuals)  139   206.23       1.4837
# ──────────────────────────────────────────────────────────

# %% [raw]
# ::: callout-warning
# ## Question
#
# Did your results change? Which variables are no longer significant?
# :::

# %% [raw]
# ::: callout-note
# ## Answer
#
# Sex and type of learner are no longer significant.
# :::

# %% [raw]
# ::: callout-caution
# ## Exercise
#
# Remove not significant variables and run the model again.
# :::

# %%
#| code-fold: true
model2_nb = glm(
  @formula(Days ~ Eth + Age), 
  quine, NegativeBinomial(2.0),
  LogLink()
)

aov.anova(model2_nb, type=3)
# Out:
# Analysis of Variance
#
# Type 3 test / F test
#
# Days ~ 1 + Eth + Age
#
# Table:
# ──────────────────────────────────────────────────────────
#              DOF  ΔDeviance  Mean ΔDev   F value  Pr(>|F|)
# ──────────────────────────────────────────────────────────
# (Intercept)    1     394.12   394.12    250.9260    <1e-32
# Eth            1      19.01    19.01     12.1032    0.0007
# Age            3      17.03     5.6759    3.6137    0.0149
# (Residuals)  141     221.47     1.5707
# ──────────────────────────────────────────────────────────

# %% [markdown]
# We can test if the two models are significantly different, if they are not (p > 0.05) it means we should keep the model with a smaller number of parameters, as they are not making the model significantly better:

# %%
aov.anova(model_nb, model2_nb)
# Out:
# ┌ Warning: Could not check whether models are nested: results may not be meaningful
# └ @ AnovaGLM ~/.julia/packages/AnovaGLM/CO3t7/src/anova.jl:162
# Analysis of Variance
#
# Type 1 test / F test
#
# Model 1: Days ~ 1 + Eth + Age
# Model 2: Days ~ 1 + Eth + Sex + Age + Lrn
#
# Table:
# ─────────────────────────────────────────────────────────────
#    DOF  ΔDOF  Res.DOF  Deviance  ΔDeviance  F value  Pr(>|F|)
# ─────────────────────────────────────────────────────────────
# 1    6            141    243.24
# 2    8     2      139    239.11     4.1240   1.3898    0.2526
# ─────────────────────────────────────────────────────────────

# %% [markdown]
# The models are not statistically different and therefore, the model that has only 2 parameters is a better model. In other words, having sex and type of learner in the model, does not improve significantly the model.
#
# ### Table of coefficients

# %%
glm_coef(model2_nb |> coeftable |> DataFrame)
# Out:
# 5×5 DataFrame
#  Row │ Name             Coef.    Lower 95%  Upper 95%  Pr(>|z|)
#      │ String           Float64  Float64    Float64    Float64
# ─────┼──────────────────────────────────────────────────────────
#    1 │ (Intercept)       11.874      8.062     17.488     0.0
#    2 │ Eth: Aboriginal    1.747      1.285      2.375     0.0
#    3 │ Age: F1            0.685      0.435      1.077     0.101
#    4 │ Age: F2            1.212      0.766      1.916     0.412
#    5 │ Age: F3            1.293      0.802      2.082     0.292

# %% [markdown]
# ### Effect plot

# %%
eff_nb = effects(
  Dict(
    :Eth => levels(quine.Eth),
    :Age => levels(quine.Age)
  ),
  model2_nb, invlink=exp
)

eff_nb |> head
# Out:
# 5×6 DataFrame
#  Row │ Eth         Age     Days      err      lower     upper
#      │ String      String  Float64   Float64  Float64   Float64
# ─────┼───────────────────────────────────────────────────────────
#    1 │ White       F0      11.8742   2.34554   9.52861  14.2197
#    2 │ Aboriginal  F0      20.7447   4.10459  16.6401   24.8493
#    3 │ White       F1       8.12973  1.29996   6.82976   9.42969
#    4 │ Aboriginal  F1      14.203    2.36403  11.839    16.5671
#    5 │ White       F2      14.3877   2.41754  11.9702   16.8053

# %%
#| label: fig-fig1
plot(
  eff_nb,
  x=:Age, y=:Days, color=:Eth,
  ymin=:lower, ymax=:upper,
  Geom.point, Geom.errorbar,
  Guide.xlabel("Age group"),
  Guide.ylabel("Number of absent days"),
  Guide.colorkey("Ethnicity")
)
# Out:
# Plot(...)

# %% [markdown]
# # Incidence Rates

# %% [raw]
# ::: callout-tip
# ## Example
#
# We are going to use the data set `seizures`. This data set contains information on the number of seizures experienced by patients with epilepsy. The data comes from a randomised controlled trial where patients were assigned to one of two treatments (new treatment or standard treatment) and there was variable amount of follow-up. The research question is: Can the new treatment reduce the rate of seizures in comparison to the standard treatment?
# :::

# %%
seizures = read_rds("data/seizures.rds") |> rcopy
seizures |> schema
# Out:
# ┌────────┬───────────────┬──────────────────────────────────┐
# │ names  │ scitypes      │ types                            │
# ├────────┼───────────────┼──────────────────────────────────┤
# │ id     │ Continuous    │ Float64                          │
# │ treat  │ Multiclass{2} │ CategoricalValue{String, UInt32} │
# │ nseize │ Continuous    │ Float64                          │
# │ pweeks │ Continuous    │ Float64                          │
# └────────┴───────────────┴──────────────────────────────────┘

# %% [raw]
# ::: callout-note
# The follow-up time, `pweeks`, is included as an offset in the model, as we do not need a coefficient to be estimated. The back-transformed results become incidence rate ratios.
# :::

# %%
model_sei = glm(
  @formula(nseize ~ treat),
  seizures, offset=log.(seizures.pweeks),
  Poisson(),
  LogLink()
)
# Out:
# StatsModels.TableRegressionModel{GeneralizedLinearModel{GLM.GlmResp{Vector{Float64}, Poisson{Float64}, LogLink}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# nseize ~ 1 + treat
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────
#                 Coef.  Std. Error     z  Pr(>|z|)   Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────
# (Intercept)  0.674798   0.0962249  7.01    <1e-11   0.486201    0.863395
# treat: New   0.21024    0.131131   1.60    0.1089  -0.0467727   0.467253
# ────────────────────────────────────────────────────────────────────────

# %%
glm_coef(model_sei |> coeftable |> DataFrame)
# Out:
# 2×5 DataFrame
#  Row │ Name         Coef.    Lower 95%  Upper 95%  Pr(>|z|)
#      │ String       Float64  Float64    Float64    Float64
# ─────┼──────────────────────────────────────────────────────
#    1 │ (Intercept)    1.964      1.626      2.371     0.0
#    2 │ treat: New     1.234      0.954      1.596     0.109

# %%
deviance(model_sei) / dof_residual(model_sei) |> r3
# Out:
# 5.935

# %% [raw]
# ::: callout-warning
# ## Question
#
# Do you think you may have overdispersion? Does your model fit the data? What can we do about it?
# :::

# %% [raw]
# ::: callout-note
# ## Answer
#
# The deviance is about 6 times greater than the degrees of freedom from the residuals, which indicates overdispersion, indicting that our model is not appropriate for explaining the variability in the data. We can perform a negative binomial regression model to account for the overdispersion.
# :::

# %%
model_snb = glm(
  @formula(nseize ~ treat),
  seizures, offset=log.(seizures.pweeks),
  NegativeBinomial(),
  LogLink()
);

# %%
glm_coef(model_snb |> coeftable |> DataFrame)
# Out:
# 2×5 DataFrame
#  Row │ Name         Coef.    Lower 95%  Upper 95%  Pr(>|z|)
#      │ String       Float64  Float64    Float64    Float64
# ─────┼──────────────────────────────────────────────────────
#    1 │ (Intercept)    2.17       1.268      3.714     0.005
#    2 │ treat: New     1.384      0.651      2.944     0.399
