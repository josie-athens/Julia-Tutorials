# %% [raw]
# ---
# title: "Extensions to Logistic Regression"
# author: Josie Athens
# date: today
# highlight-style: ayu
# format:
#   html:
#     code-fold: false
#     theme: mint
#     toc: true
#     number-sections: true
#     toc-title: Contents
#     smooth-scroll: true
#     embed-resources: true
# execute:
#   cache: true
#   warning: false
# ---

# %% [markdown]
# # [📖 Main Menu](index.html)

# %%
using StatsBase, DataFrames, DataFrameMacros
using RCall, CategoricalArrays, TexTables
using Distributions, Gadfly, Compose, MLJ
using Effects, MultipleTesting
using Econometrics, GLM
import AnovaGLM as aov

using MLJ: schema, Continuous

# %%
include("pubh.jl")
@rlibrary readr
@rimport pubh

# %%
#| output: false
R"""
library(pubh)
library(sjlabelled)
""";
# Out:
# ┌ Warning: RCall.jl: Loading required package: emmeans
# │ Loading required package: ggformula
# │ Loading required package: ggplot2
# │ Loading required package: scales
# │ Loading required package: ggridges
# │
# │ New to ggformula?  Try the tutorials:
# │ 	learnr::run_tutorial("introduction", package = "ggformula")
# │ 	learnr::run_tutorial("refining", package = "ggformula")
# │ Loading required package: gtsummary
# │ Loading required package: huxtable
# │
# │ Attaching package: ‘huxtable’
# │
# │ The following object is masked from ‘package:gtsummary’:
# │
# │     as_flextable
# │
# │ The following object is masked from ‘package:scales’:
# │
# │     number_format
# │
# │ The following object is masked from ‘package:ggplot2’:
# │
# │     theme_grey
# │
# │ Loading required package: magrittr
# └ @ RCall ~/.julia/packages/RCall/dDAVd/src/io.jl:172
# ┌ Warning: RCall.jl:
# │ Attaching package: ‘sjlabelled’
# │
# │ The following object is masked from ‘package:huxtable’:
# │
# │     set_label
# │
# │ The following object is masked from ‘package:ggplot2’:
# │
# │     as_label
# │
# └ @ RCall ~/.julia/packages/RCall/dDAVd/src/io.jl:172

# %% [markdown]
# # Interactions
#
# We are going to look at a different way to test for interactions, try to think about biological interactions more than on statistical interactions.

# %% [raw]
# ::: callout-tip
# ## Example
#
# We follow an example from Rothman regarding the effect of oral contraceptives and hypertension on strokes in young women.
# :::

# %%
R"""
data(Rothman)

levels(Rothman$stroke) = c("No stroke", "Stroke")
levels(Rothman$ht) = c("No-Hypertension", "Hypertension")
""";

# %%
rothman = @rget Rothman
rothman |> head
# Out:
# 5×3 DataFrame
#  Row │ stroke     oc        ht
#      │ Cat…       Cat…      Cat…
# ─────┼──────────────────────────────────────
#    1 │ No stroke  Non-user  No-Hypertension
#    2 │ No stroke  Non-user  No-Hypertension
#    3 │ No stroke  Non-user  No-Hypertension
#    4 │ No stroke  Non-user  No-Hypertension
#    5 │ No stroke  Non-user  No-Hypertension

# %% [raw]
# ::: callout-caution
# ## Exercise
#
# Perform descriptive statistics showing the distribution of stroke by hypertensive status and stratified by oral contraceptives usage.
# :::

# %%
#| code-fold: true
#| output: asis
R"""
Rothman %>% 
  select(stroke, ht, oc) |> 
    mutate(
    stroke = relevel(stroke, ref = "Stroke"),
    ht = relevel(ht, ref = "Hypertension"),
    oc = relevel(oc, ref = "User")
  ) |> 
  copy_labels(Rothman) |> 
  tbl_strata(
    strata = oc,
    .tbl_fun = ~ .x |> 
      tbl_summary(by = ht, missing = "no")
  ) |>  
  cosm_sum(bold = TRUE) |> set_font_size(10) |> theme_pubh(2) |> 
  set_align(1, everywhere, "center") |>
  set_right_border(everywhere, 3) |>
  print_html()
""";
# Out:
# <table class="huxtable" data-quarto-disable-processing="true" style="border-collapse: collapse; border: 0px; margin-bottom: 2em; margin-top: 2em; ; margin-left: auto; margin-right: auto;  ">
# <col><col><col><col><col><tr>
# <th style="vertical-align: top; text-align: center; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"></th><th colspan="2" style="vertical-align: top; text-align: center; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0.4pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>User</strong></p>
# </th><th colspan="2" style="vertical-align: top; text-align: center; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0.4pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>Non-user</strong></p>
# </th></tr>
# <tr>
# <th style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>Variable</strong></p>
# </th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>Hypertension</strong>, N = 33</p>
# </th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0.4pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>No-Hypertension</strong>, N = 70</p>
# </th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0.4pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>Hypertension</strong>, N = 104</p>
# </th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>No-Hypertension</strong>, N = 270</p>
# </th></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;">Thrombotic stroke</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0.4pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0.4pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;"></td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal; font-size: 10pt;">Stroke</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">24 (73%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0.4pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">31 (44%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0.4pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">43 (41%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">37 (14%)</td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal; font-size: 10pt;">No stroke</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">9 (27%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0.4pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">39 (56%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0.4pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">61 (59%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">233 (86%)</td></tr>
# </table>

# %% [markdown]
# ### Mantel-Haenszel approach
#
# We can start with a stratified analysis (Mantel-Haenszel):

# %%
pubh.mhor(@formula(stroke ~ ht/oc), data = rothman) |> rcopy
# Out:
#                            OR Lower.CI Upper.CI Pr(>|z|)
# htNo-Hypertension:ocUser 5.01     2.79     8.99  < 0.001
# htHypertension:ocUser    3.78     1.60     8.94    0.002
#
#                           Common OR Lower CI Upper CI Pr(>|z|)
# Cochran-Mantel-Haenszel:       4.52     2.77     7.37  < 0.001
#
# Test for effect modification (interaction): p =  0.6001

# %% [raw]
# ::: callout-warning
# ## Question
#
# What are your conclusions?
# :::

# %% [raw]
# ::: callout-note
# ## Answer
#
# The odds of having thrombotic stroke is 4.52 times more in users of oral contraceptives than in non-users (95% CIs: 2.77, 7.37) adjusted for history of hypertension. The effect of oral contraceptives on having  stroke is statistically significant ($p$ < 0.001) and is not different between women with a history of hypertension and women without history of hypertension (p = 0.600).
# :::

# %% [markdown]
# ## Statistical interactions

# %% [markdown]
# From the test of effect modification, we know that the interaction between use of oral contraceptives and history of hypertension was not significant. Let's compare with the logistic regression approach.

# %% [raw]
# ::: callout-important
# Remember that for `glm` the outcome has to be an Integer.
# :::

# %%
rothman.stroke_cont = coerce(rothman.stroke, Continuous) .- 1;

# %%
roth_1 = glm(@formula(stroke_cont ~ oc * ht), rothman, Binomial(), LogitLink())
# Out:
# StatsModels.TableRegressionModel{GeneralizedLinearModel{GLM.GlmResp{Vector{Float64}, Binomial{Float64}, LogitLink}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# stroke_cont ~ 1 + oc + ht + oc & ht
#
# Coefficients:
# ──────────────────────────────────────────────────────────────────────────────────────────
#                                  Coef.  Std. Error       z  Pr(>|z|)  Lower 95%  Upper 95%
# ──────────────────────────────────────────────────────────────────────────────────────────
# (Intercept)                  -1.84012     0.176846  -10.41    <1e-24   -2.18673  -1.49351
# oc: User                      1.61054     0.298618    5.39    <1e-07    1.02526   2.19582
# ht: Hypertension              1.49045     0.266309    5.60    <1e-07    0.96849   2.0124
# oc: User & ht: Hypertension  -0.280045    0.530405   -0.53    0.5975   -1.31962   0.759529
# ──────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# Corresponding OR:

# %%
glm_coef(roth_1 |> coeftable |> DataFrame)[2:end, :]
# Out:
# 3×5 DataFrame
#  Row │ Name                         Coef.    Lower 95%  Upper 95%  Pr(>|z|)
#      │ String                       Float64  Float64    Float64    Float64
# ─────┼──────────────────────────────────────────────────────────────────────
#    1 │ oc: User                       5.006      2.788      8.987     0.0
#    2 │ ht: Hypertension               4.439      2.634      7.481     0.0
#    3 │ oc: User & ht: Hypertension    0.756      0.267      2.137     0.598

# %% [raw]
# ::: callout-caution
# ## Exercise
#
# Construct the effect plot of oral contraceptive usage by history of hypertension.
# :::

# %%
#| code-fold: true
eff_1 = effects(
    Dict(
        :ht => levels(rothman.ht),
        :oc => levels(rothman.oc)
    ),
    roth_1, invlink=inv_logit
)
# Out:
# 4×6 DataFrame
#  Row │ ht               oc        stroke_cont  err        lower     upper
#      │ String           String    Float64      Float64    Float64   Float64
# ─────┼───────────────────────────────────────────────────────────────────────
#    1 │ No-Hypertension  Non-user     0.137037  0.0209134  0.116124  0.157951
#    2 │ Hypertension     Non-user     0.413462  0.048287   0.365175  0.461749
#    3 │ No-Hypertension  User         0.442857  0.0593694  0.383488  0.502226
#    4 │ Hypertension     User         0.727272  0.0774599  0.649812  0.804732

# %%
#| label: fig-fig1
#| fig-cap: "Effect of oral contraceptive usage on the probability of developing stroke, by history of hypertension."
#| code-fold: true
plot(
  eff_1,
  x=:oc, y=:stroke_cont, color=:ht,
  ymin=:lower, ymax=:upper,
  Geom.point, Geom.errorbar,
  Guide.xlabel("Oral contraceptives"),
  Guide.ylabel("P (Stroke)"),
  Guide.colorkey("Hypertension")
)
# Out:
# Plot(...)

# %% [markdown]
# ### Joined exposures

# %% [markdown]
# The $p$−value of the interaction term ($p$ = 0.598) is the same as the test of homogeneity (if robust standard errors are not used).
#
# From a epidemiological (biological) point of view, we might be interested in testing what is the effect of both oral contraceptive use and history of hypertension (exposure) on stroke. We can generate a new variable (join) with different levels of exposure (based upon the combinations):

# %%
rothman.join .= 0
n = nrow(rothman)

for i in 1:n
  if rothman.oc[i] == "Non-user" && rothman.ht[i] == "Hypertension"
    rothman.join[i] = 1
  elseif rothman.oc[i] == "User" && rothman.ht[i] == "No-Hypertension"
    rothman.join[i] = 2
  elseif rothman.oc[i] == "User" && rothman.ht[i] == "Hypertension"
    rothman.join[i] = 3
  else
    rothman.join[i] = 0
  end
end

rothman.join = recode(
  rothman.join,
  0 => "Unexposed",
  1 => "Hypertension",
  2 => "OC user",
  3 => "OC+hypertension"
)

coerce!(rothman, :join => Multiclass)
levels!(rothman.join, ["Unexposed", "Hypertension", "OC user", "OC+hypertension"])

tabulate(rothman, :join)
# Out:
#                 | Freq. | Percent |  Cum.
# --------------------------------------------
#       Unexposed |   270 |  56.604 |  56.604
#    Hypertension |   104 |  21.803 |  78.407
#         OC user |    70 |  14.675 |  93.082
# OC+hypertension |    33 |   6.918 | 100.000
# --------------------------------------------
#           Total |   477 | 100.000 |

# %% [markdown]
# Now, we perform the logistic regression using `join` as our only predictor:

# %%
roth_2 = glm(@formula(stroke_cont ~ join), rothman, Binomial(), LogitLink())
# Out:
# StatsModels.TableRegressionModel{GeneralizedLinearModel{GLM.GlmResp{Vector{Float64}, Binomial{Float64}, LogitLink}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# stroke_cont ~ 1 + join
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────────────────
#                           Coef.  Std. Error       z  Pr(>|z|)  Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────────────────
# (Intercept)            -1.84012    0.176846  -10.41    <1e-24   -2.18673   -1.49351
# join: Hypertension      1.49045    0.266309    5.60    <1e-07    0.96849    2.0124
# join: OC user           1.61054    0.298618    5.39    <1e-07    1.02526    2.19582
# join: OC+hypertension   2.82095    0.428702    6.58    <1e-10    1.98071    3.66118
# ───────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# Corresponding OR:

# %%
glm_coef(roth_2 |> coeftable |> DataFrame)[2:end, :]
# Out:
# 3×5 DataFrame
#  Row │ Name                   Coef.    Lower 95%  Upper 95%  Pr(>|z|)
#      │ String                 Float64  Float64    Float64    Float64
# ─────┼────────────────────────────────────────────────────────────────
#    1 │ join: Hypertension       4.439      2.634      7.481       0.0
#    2 │ join: OC user            5.006      2.788      8.987       0.0
#    3 │ join: OC+hypertension   16.793      7.248     38.907       0.0

# %% [markdown]
# Look at the odds ratios. The join exposure has about 3 times more the effect of the single exposures. We can look at the trend in odds.

# %%
R"""
stroke_df = odds_trend(stroke ~ join, data = $rothman)$df
""";

# %%
@rget stroke_df
# Out:
# 4×6 DataFrame
#  Row │ Exposure         OR       lower       upper       chi_square  fisher_ex ⋯
#      │ Cat…             Float64  Float64?    Float64?    String?     String?   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Unexposed           1.0   missing     missing     missing     missing   ⋯
#    2 │ Hypertension        4.44        2.63        7.48  < 0.001     < 0.001
#    3 │ OC user             5.01        2.79        8.99  < 0.001     < 0.001
#    4 │ OC+hypertension    16.79        7.24       38.94  < 0.001     < 0.001
#                                                                 1 column omitted

# %%
#| label: fig-fig2
#| fig-cap: "Effect of different levels of exposure on thrombotic stroke."
effect_plot(
  stroke_df, :Exposure, :OR,
  xlab="Exposure", ylab="OR"
)
# Out:
# Plot(...)

# %% [markdown]
# Is the trend significant?

# %%
roth_2 |> aov.anova
# Out:
# Analysis of Variance
#
# Type 1 test / Likelihood-ratio test
#
# stroke_cont ~ 1 + join
#
# Table:
# ──────────────────────────────────────────────
#              DOF  Deviance       χ²  Pr(>|χ²|)
# ──────────────────────────────────────────────
# (Intercept)    1    568.38  92.8864     <1e-21
# join           3    491.60  76.7794     <1e-15
# ──────────────────────────────────────────────

# %% [markdown]
# Why do we have different results regarding the interaction term? Because we are testing different things. The first model, `roth_1`, is testing if the effect of oral contraceptives use on stroke is different between women with a history of hypertension and women without a history of hypertension; that was not the case. The second model, `roth_2`, is testing if both the use of oral contraceptives and history of hypertension has an effect on stroke, and that was the case. Strictly speaking, our second model is not looking for interaction, but the effect of a combination of predictors.
#
# The results from the second model, show that women with a history of hypertension and who are users of oral contraceptives are 16.79 times more likely to have stroke than unexposed women (OR: 16.79, 95% CIs: 5.62, 50.17) vs. the unexposed group ($p$ < 0.001).

# %% [markdown]
# # Conditional Logistic Regression
#
# Conditional logistic regression is used for matched case-control studies.
#
# Matching is a way of controlling for confounding during the design stage of the study. Each case is paired with one or more controls according to levels of specified predictors.

# %% [raw]
# ::: callout-tip
# ## Example
#
# We will look at a matched case-control study investigating the association between the use of oestrogen and endometrial cancer. Four controls were matched to each case by age and marital status.
# :::

# %%
R"""
data(bdendo, package = "Epi")

bdendo = bdendo |>
mutate(
    cancer = factor(d, labels = c('Control', 'Case')),
    gall = factor(gall, labels = c("No GBD", "GBD")),
    est = factor(est, labels = c("No oestrogen", "Oestrogen"))
  ) |>
  var_labels(
    cancer = 'Endometrial cancer',
    gall = 'Gall bladder disease',
    est = 'Oestrogen'
  )
""";

# %%
@rget bdendo
bdendo |> schema
# Out:
# ┌──────────┬───────────────────────────────┬────────────────────────────────────
# │ names    │ scitypes                      │ types                             ⋯
# ├──────────┼───────────────────────────────┼────────────────────────────────────
# │ set      │ Continuous                    │ Float64                           ⋯
# │ d        │ Continuous                    │ Float64                           ⋯
# │ gall     │ Multiclass{2}                 │ CategoricalValue{String, UInt32}  ⋯
# │ hyp      │ Multiclass{2}                 │ CategoricalValue{String, UInt32}  ⋯
# │ ob       │ Union{Missing, Multiclass{2}} │ Union{Missing, CategoricalValue{S ⋯
# │ est      │ Multiclass{2}                 │ CategoricalValue{String, UInt32}  ⋯
# │ dur      │ Union{Missing, Multiclass{5}} │ Union{Missing, CategoricalValue{S ⋯
# │ non      │ Multiclass{2}                 │ CategoricalValue{String, UInt32}  ⋯
# │ duration │ Union{Missing, Continuous}    │ Union{Missing, Float64}           ⋯
# │ age      │ Continuous                    │ Float64                           ⋯
# │ cest     │ Union{Missing, Multiclass{4}} │ Union{Missing, CategoricalValue{S ⋯
# │ agegrp   │ Multiclass{6}                 │ CategoricalValue{String, UInt32}  ⋯
# │ age3     │ Multiclass{3}                 │ CategoricalValue{String, UInt32}  ⋯
# │ cancer   │ Multiclass{2}                 │ CategoricalValue{String, UInt32}  ⋯
# └──────────┴───────────────────────────────┴────────────────────────────────────
#                                                                 1 column omitted

# %%
coerce!(bdendo, :set => Multiclass);

# %% [raw]
# ::: callout-caution
# ## Exercise
#
# Perform descriptive analysis to show the distribution of endometrial cancer by gall bladder disease stratified by oral contraceptive usage.
# :::

# %%
#| output: asis
#| code-fold: true
R"""
bdendo |> 
  select(cancer, gall, est) |> 
    mutate(
    cancer = relevel(cancer, ref = "Case"),
    gall = relevel(gall, ref = "GBD"),
    est = relevel(est, ref = "Oestrogen")
  ) |>
  copy_labels(bdendo) |>
  tbl_strata(
    strata = gall,
    .tbl_fun = ~ .x |>
      tbl_summary(by = est, missing = "no")
  ) |> 
  cosm_sum(bold = TRUE) |> set_font_size(10) |> theme_pubh(2) |> 
  set_align(1, everywhere, "center") |>
  set_right_border(everywhere, 3) |>
  print_html()
""";
# Out:
# <table class="huxtable" data-quarto-disable-processing="true" style="border-collapse: collapse; border: 0px; margin-bottom: 2em; margin-top: 2em; ; margin-left: auto; margin-right: auto;  ">
# <col><col><col><col><col><tr>
# <th style="vertical-align: top; text-align: center; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"></th><th colspan="2" style="vertical-align: top; text-align: center; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0.4pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>GBD</strong></p>
# </th><th colspan="2" style="vertical-align: top; text-align: center; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0.4pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>No GBD</strong></p>
# </th></tr>
# <tr>
# <th style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>Variable</strong></p>
# </th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>Oestrogen</strong>, N = 29</p>
# </th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0.4pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>No oestrogen</strong>, N = 12</p>
# </th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0.4pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>Oestrogen</strong>, N = 154</p>
# </th><th style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;"><p><strong>No oestrogen</strong>, N = 120</p>
# </th></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: bold; font-size: 10pt;">Endometrial cancer</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0.4pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0.4pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;"></td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0.4pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;"></td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal; font-size: 10pt;">Case</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">13 (45%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0.4pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">4 (33%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0.4pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">43 (28%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">3 (2.5%)</td></tr>
# <tr>
# <td style="vertical-align: top; text-align: left; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 15pt; font-weight: normal; font-size: 10pt;">Control</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">16 (55%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0.4pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">8 (67%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0.4pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">111 (72%)</td><td style="vertical-align: top; text-align: right; white-space: normal; border-style: solid solid solid solid; border-width: 0pt 0pt 0.4pt 0pt;    padding: 3pt 6pt 3pt 6pt; font-weight: normal; font-size: 10pt;">117 (98%)</td></tr>
# </table>

# %% [markdown]
# ## Unadjusted analysis
#
# We will start with the unadjusted analysis.

# %%
using MixedModels

# %%
endom_1 = fit(
  MixedModel,
  @formula(d ~ 1 + est + (1 | set)),
  bdendo, Bernoulli()
);

# %%
endom_1 |> coeftable |> DataFrame
# Out:
# 2×5 DataFrame
#  Row │ Name            Coef.     Std. Error  z         Pr(>|z|)
#      │ String          Float64   Float64     Float64   Float64
# ─────┼─────────────────────────────────────────────────────────────
#    1 │ (Intercept)     -2.88238    0.3884    -7.42118  1.16085e-13
#    2 │ est: Oestrogen   2.06355    0.420221   4.91063  9.07841e-7

# %%
exp.(coef(endom_1))[2] |> r3
# Out:
# 7.874

# %% [markdown]
# Corresponding 95% CI:

# %%
exp(coef(endom_1)[2] - 1.96*0.420221) |> r3, exp(coef(endom_1)[2] + 1.96*0.420221) |> r3
# Out:
# (3.455, 17.943)

# %% [raw]
# ::: callout-warning
# ## Question
#
# What are your conclusions?
# :::

# %% [raw]
# ::: callout-note
# ## Answer
#
# When not adjusting for confounders, the odds of developing endometrial cancer is 7.87 times more (95% CIs: 3.46, 17.94) in women with a history of oestrogen use in comparison to women without a history of oestrogen use ($p$ < 0.001).
# :::

# %% [markdown]
# ## Adjusted analysis
#
# Effect of oestrogen use on endometrial cancer controlling for history of gall bladder disease.

# %%
endom_2 = fit(
  MixedModel,
  @formula(d ~ est * gall + (1 | set)),
  bdendo, Binomial()
);

# %%
endom_2 |> coeftable |> DataFrame
# Out:
# 4×5 DataFrame
#  Row │ Name                        Coef.     Std. Error  z         Pr(>|z|)    ⋯
#      │ String                      Float64   Float64     Float64   Float64     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ (Intercept)                 -3.66339    0.584657  -6.26587  3.70739e-10 ⋯
#    2 │ est: Oestrogen               2.71511    0.611627   4.43915  9.03146e-6
#    3 │ gall: GBD                    2.97034    0.846647   3.50836  0.000450873
#    4 │ est: Oestrogen & gall: GBD  -2.22968    0.942602  -2.36546  0.0180078

# %%
r3.(exp.(coef(endom_2)))
# Out:
# 4-element Vector{Float64}:
#   0.026
#  15.106
#  19.499
#   0.108

# %% [markdown]
# We can understand better the interaction term by looking at its corresponding effect plot.
#
# Creating data frame for effect plot:

# %%
endom_eff = effects(
  Dict(
    :est => levels(bdendo.est),
    :gall => levels(bdendo.gall)
  ),
  endom_2, invlink=inv_logit
)
# Out:
# 4×6 DataFrame
#  Row │ est           gall    d          err        lower      upper
#      │ String        String  Float64    Float64    Float64    Float64
# ─────┼──────────────────────────────────────────────────────────────────
#    1 │ No oestrogen  No GBD  0.0250042  0.0142534  0.0107509  0.0392576
#    2 │ Oestrogen     No GBD  0.27923    0.0361509  0.24308    0.315381
#    3 │ No oestrogen  GBD     0.333356   0.136085   0.197271   0.469442
#    4 │ Oestrogen     GBD     0.448281   0.0923496  0.355931   0.54063

# %%
#| label: fig-fig3
#| fig-cap: "Effect of oestrogen on endometrial cancer by gall bladder disease (GBD)."
plot(
  endom_eff, 
  x=:est, y=:d, color=:gall,
  ymin=:lower, ymax=:upper,
  Geom.point, Geom.errorbar,
  Guide.xlabel("OC use"),
  Guide.ylabel("P(Endometrial cancer)"),
  Guide.colorkey("Gall bladder disease")
)
# Out:
# Plot(...)

# %% [raw]
# ::: callout-warning
# ## Question
#
# What are your conclusions from the interaction plot?
# :::

# %% [raw]
# ::: callout-note
# ## Answer
#
# In women without a history of gall bladder disease, oestrogen consumers are more likely to develop endometrial cancer than non-oestrogen consumers; i.e., oestrogen use has a positive effect on the development of endometrial cancer. In women with a history of gall bladder disease, there is no significant effect of oestrogen consumption in the development of endometrial cancer.
# :::

# %% [markdown]
# # Ordinal Logistic Regression
#
# So far, we have considered situations where the outcome was binary. What analysis do we perform if the outcome has more than two categories and is ordinal?
#
# Examples of ordinal variables:
#
# - The level of agreement: strongly disagree, disagree, neutral, agree, strongly agree.
# - A form of disease: mild, moderate, severe.

# %% [raw]
# ::: callout-tip
# ## Example
#
# We will use data from a questionnaire on the benefits of mammography.
# :::

# %%
mammo = rcopy(R"TH.data::mammoexp")
mammo |> head
# Out:
# 5×6 DataFrame
#  Row │ ME             SYMPT              PB     HIST  BSE   DECT
#      │ Cat…           Cat…               Int64  Cat…  Cat…  Cat…
# ─────┼──────────────────────────────────────────────────────────────────────
#    1 │ Never          Disagree               7  No    Yes   Somewhat likely
#    2 │ Never          Agree                 11  No    Yes   Very likely
#    3 │ Never          Disagree               8  Yes   Yes   Very likely
#    4 │ Within a Year  Disagree              11  No    Yes   Very likely
#    5 │ Over a Year    Strongly Disagree      7  No    Yes   Very likely

# %% [markdown]
# Our outcome of interest is `ME` (mammography experience), and ordinal variable.

# %%
tabulate(mammo, :ME)
# Out:
#               | Freq. | Percent |  Cum.
# ------------------------------------------
#         Never |   234 |  56.796 |  56.796
# Within a Year |   104 |  25.243 |  82.039
#   Over a Year |    74 |  17.961 | 100.000
# ------------------------------------------
#         Total |   412 | 100.000 |

# %% [markdown]
# If $y$ is the ordinal outcome with levels $1,2,\dots,k$, then the proportional odds ordinal logistic model can be written as a series of logistic models:
#
# $$
# \begin{gather}
#  P(y>1) & = & \text{logit}^{-1}(\beta x) \\
#  P(y>2) & = & \text{logit}^{-1}(\beta x - c_2) \\
#  \vdots & & \vdots \\
#  P(y>[k-1]) & = & \text{logit}^{-1}(\beta x - c_{k-1})
# \end{gather}
# $$
#
# Hence $e^{\beta}$ is the odds ratio of being in a higher category for a one unit change in the predictor variable.
#
# When we have three groups, we are comparing: unlikely vs. (somewhat likely and very likely) and (unlikely and somewhat likely) vs. (very likely).
#
# With the proportional odds assumption (parallel regression assumption) we assume that the relationship between each pair of outcome groups is the same. Hence, there is only one model. If this assumption did not hold, we would need different models to describe the relationship between each pair of outcome variables. We should test this hypothesis before we report the results.

# %% [raw]
# ::: callout-important
# For the model to work, the response variable has to be defined as an `OrderedFactor`.
# :::

# %%
coerce!(
  mammo,
  :ME => OrderedFactor,
  :SYMPT => OrderedFactor
  );

# %%
mammo_1 = fit(
  EconometricModel,
  @formula(ME ~ SYMPT + PB + HIST + BSE + DECT),
  mammo
)
# Out:
# Probability Model for Ordinal Response
# Categories: Never < Within a Year < Over a Year
# Number of observations: 412
# Null Loglikelihood: -402.60
# Loglikelihood: -363.56
# R-squared: 0.0970
# LR Test: 78.08 ∼ χ²(8) ⟹ Pr > χ² = 0.0000
# Formula: ME ~ SYMPT + PB + HIST + BSE + DECT
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                               PE         SE       t-value  Pr > |t|      2.50%      97.50%
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────
# SYMPT: Agree                              -0.126848  0.548065   -0.231446    0.8171  -1.20426    0.950568
# SYMPT: Disagree                            1.20629   0.462617    2.60754     0.0095   0.296855   2.11573
# SYMPT: Strongly Disagree                   1.4707    0.464212    3.16818     0.0017   0.558133   2.38328
# PB                                        -0.15037   0.0572979  -2.62436     0.0090  -0.263009  -0.0377308
# HIST: Yes                                  0.751022  0.30133     2.49235     0.0131   0.15865    1.34339
# BSE: Yes                                   1.07993   0.387847    2.78443     0.0056   0.317484   1.84238
# DECT: Somewhat likely                     -0.842747  0.653344   -1.2899      0.1978  -2.12713    0.441633
# DECT: Very likely                         -0.471193  0.633511   -0.743779    0.4574  -1.71658    0.774198
# (Intercept): Never | Within a Year         0.707776  0.935192    0.756824    0.4496  -1.13067    2.54623
# (Intercept): Within a Year | Over a Year   2.12927   0.940811    2.26322     0.0242   0.279771   3.97876
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# Let's remove `DECT` from the model:

# %%
mammo_2 = fit(
  EconometricModel,
  @formula(ME ~ SYMPT + PB + HIST + BSE),
  mammo
)
# Out:
# Probability Model for Ordinal Response
# Categories: Never < Within a Year < Over a Year
# Number of observations: 412
# Null Loglikelihood: -402.60
# Loglikelihood: -364.96
# R-squared: 0.0935
# LR Test: 75.27 ∼ χ²(6) ⟹ Pr > χ² = 0.0000
# Formula: ME ~ SYMPT + PB + HIST + BSE
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                               PE        SE       t-value  Pr > |t|      2.50%      97.50%
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────
# SYMPT: Agree                              -0.120306  0.548382  -0.219384    0.8265  -1.19833    0.957716
# SYMPT: Disagree                            1.27483   0.458285   2.78175     0.0057   0.373924   2.17574
# SYMPT: Strongly Disagree                   1.53564   0.458085   3.3523      0.0009   0.635125   2.43616
# PB                                        -0.153462  0.05573   -2.75367     0.0062  -0.263018  -0.0439069
# HIST: Yes                                  0.771167  0.300763   2.56403     0.0107   0.179919   1.36241
# BSE: Yes                                   1.03564   0.384588   2.69285     0.0074   0.279605   1.79167
# (Intercept): Never | Within a Year         1.23865   0.690452   1.79397     0.0736  -0.11866    2.59595
# (Intercept): Within a Year | Over a Year   2.65544   0.699464   3.7964      0.0002   1.28042    4.03047
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# We will create a data frame with the table of coefficients.

# %%
mammo_coef = coeftable(mammo_2) |> DataFrame
mammo_coef |> head
# Out:
# 5×7 DataFrame
#  Row │ Name                      PE         SE        t-value    Pr > |t|      ⋯
#      │ String                    Float64    Float64   Float64    Float64       ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ SYMPT: Agree              -0.120306  0.548382  -0.219384  0.826461      ⋯
#    2 │ SYMPT: Disagree            1.27483   0.458285   2.78175   0.00565878
#    3 │ SYMPT: Strongly Disagree   1.53564   0.458085   3.3523    0.000876605
#    4 │ PB                        -0.153462  0.05573   -2.75367   0.00615776
#    5 │ HIST: Yes                  0.771167  0.300763   2.56403   0.0107054     ⋯
#                                                                2 columns omitted

# %% [markdown]
# Corresponding table of coefficients showing Odds Ratios and confindence intervals:

# %%
mammo_exp = DataFrame(
	;
	Variable = mammo_coef[1:6, 1],
	ME = exp.(mammo_coef[1:6, 2]),
	lower = exp.(mammo_coef[1:6, 6]),
	upper = exp.(mammo_coef[1:6, 7])
)
# Out:
# 6×4 DataFrame
#  Row │ Variable                  ME        lower     upper
#      │ String                    Float64   Float64   Float64
# ─────┼─────────────────────────────────────────────────────────
#    1 │ SYMPT: Agree              0.886649  0.301698   2.60574
#    2 │ SYMPT: Disagree           3.5781    1.45343    8.80868
#    3 │ SYMPT: Strongly Disagree  4.6443    1.88726   11.429
#    4 │ PB                        0.857733  0.768728   0.957043
#    5 │ HIST: Yes                 2.16229   1.19712    3.90561
#    6 │ BSE: Yes                  2.8169    1.32261    5.99946

# %%
#| label: fig-fig4
#| fig-cap: "Coefficient plot for ordinal model predicting mammography experience."
plot(
  mammo_exp,
  x=:ME, y=:Variable,
  xmin=:lower, xmax=:upper, xintercept=[1],
  Geom.point, Geom.errorbar,
  Geom.vline(
    style=[:dash],
    size=[0.2mm],
    color=["cadetblue"]
    )
)
# Out:
# Plot(...)
