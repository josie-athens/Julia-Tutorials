# %% [raw]
# ---
# title: Introduction to Machine Learning
# subtitle: Classification
# author: Josie Athens
# date: today
# highlight-style: ayu
# format:
#   html:
#     code-fold: false
#     theme: mint
#     toc: true
#     number-sections: true
#     toc-title: Contents
#     smooth-scroll: true
#     embed-resources: true
# execute:
#   cache: true
#   warning: false
# ---

# %% [markdown]
# # [📖 Main Menu](index.html)

# %%
using StatsBase, DataFrames, DataFrameMacros
using RCall, CategoricalArrays, TexTables
using Distributions, Gadfly, Compose, MLJ
using StableRNGs
import DecisionTree

using MLJ: schema, Continuous

# %%
include("pubh.jl")
set_default_plot_size(15cm, 12cm)

# %% [markdown]
# # Data

# %% [raw]
# ::: callout-tip
# ## Example
#
# Fisher’s iris dataset on measurements for three species of iris.
# :::

# %%
iris = rcopy(R"datasets::iris")
iris |> schema
# Out:
# ┌──────────────┬───────────────┬──────────────────────────────────┐
# │ names        │ scitypes      │ types                            │
# ├──────────────┼───────────────┼──────────────────────────────────┤
# │ Sepal_Length │ Continuous    │ Float64                          │
# │ Sepal_Width  │ Continuous    │ Float64                          │
# │ Petal_Length │ Continuous    │ Float64                          │
# │ Petal_Width  │ Continuous    │ Float64                          │
# │ Species      │ Multiclass{3} │ CategoricalValue{String, UInt32} │
# └──────────────┴───────────────┴──────────────────────────────────┘

# %% [markdown]
# We `unpack` the data to define *response* and *explanatory* variables:

# %%
y, X = unpack(iris, ==(:Species));
X |> head
# Out:
# 5×4 DataFrame
#  Row │ Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
#      │ Float64       Float64      Float64       Float64
# ─────┼──────────────────────────────────────────────────────
#    1 │          5.1          3.5           1.4          0.2
#    2 │          4.9          3.0           1.4          0.2
#    3 │          4.7          3.2           1.3          0.2
#    4 │          4.6          3.1           1.5          0.2
#    5 │          5.0          3.6           1.4          0.2

# %% [markdown]
# ## Data sppliting

# %%
rng = StableRNG(566)
train, test = partition(eachindex(y), 0.7, shuffle=true, rng=rng);

# %% [markdown]
# # Pruned Trees
#
# ## Model

# %%
using MLJDecisionTreeInterface

# %%
dtc = @load DecisionTreeClassifier pkg=DecisionTree verbosity=0
pruned_model = dtc(max_depth=2)
pruned_mach = machine(pruned_model, X, y)
# Out:
# untrained Machine; caches model-specific representations of data
#   model: DecisionTreeClassifier(max_depth = 2, …)
#   args:
#     1:	Source @850 ⏎ Table{AbstractVector{Continuous}}
#     2:	Source @343 ⏎ AbstractVector{Multiclass{3}}

# %%
fit!(pruned_mach, rows=train);
# Out:
# [ Info: Training machine(DecisionTreeClassifier(max_depth = 2, …), …).

# %% [markdown]
# ## Visualisation

# %%
fitted_params(pruned_mach).tree
# Out:
# Petal_Width < 0.75
# ├─ setosa (38/38)
# └─ Petal_Width < 1.7
#    ├─ versicolor (33/35)
#    └─ virginica (32/32)

# %%
pruned_mach |> feature_importances |> DataFrame
# Out:
# 1×4 DataFrame
#  Row │ Petal_Width  Sepal_Length  Sepal_Width  Petal_Length
#      │ Float64      Float64       Float64      Float64
# ─────┼──────────────────────────────────────────────────────
#    1 │         1.0           0.0          0.0           0.0

# %% [markdown]
# ## Performance

# %%
pruned_ŷ = MLJ.predict(pruned_mach, rows=test);
pruned_ȳ = predict_mode(pruned_mach, rows=test);

# %%
cross_entropy(pruned_ŷ, y[test]) |> mean |> r3
# Out:
# 1.013

# %%
misclassification_rate(pruned_ȳ, y[test]) |> r3
# Out:
# 0.089

# %%
accuracy(pruned_ȳ, y[test]) |> r3
# Out:
# 0.911

# %%
kappa(pruned_ȳ, y[test]) |> r3
# Out:
# 0.865

# %% [markdown]
# When we have many categories, it is easy to construct the data frame, and from that data frame, create binary variables and then construct the corresponding confussion matrix.

# %%
prune_df = DataFrame(
  hcat(
    string.(pruned_ȳ),
    string.(y[test])
  ),
  [:pred, :obs]
);

# %%
prune_df.pred_bin = prune_df.pred .== "versicolor"
prune_df.obs_bin = prune_df.obs .== "versicolor";

# %%
@rlibrary epitools
epitable(prune_df.pred_bin, prune_df.obs_bin, rev="both")
# Out:
# RObject{IntSxp}
#          Outcome
# Predictor TRUE FALSE
#     TRUE    16     3
#     FALSE    1    25

# %%
sensitivity(prune_df.pred_bin, prune_df.obs_bin) |> r3
# Out:
# ┌ Warning: Levels not explicitly ordered. Using the order Bool[0, 1]. The "positive" level is true.
# └ @ StatisticalMeasures.ConfusionMatrices ~/.julia/packages/StatisticalMeasures/Wnt7C/src/confusion_matrices.jl:333
# 0.941

# %%
specificity(prune_df.pred_bin, prune_df.obs_bin) |> r3
# Out:
# ┌ Warning: Levels not explicitly ordered. Using the order Bool[0, 1]. The "positive" level is true.
# └ @ StatisticalMeasures.ConfusionMatrices ~/.julia/packages/StatisticalMeasures/Wnt7C/src/confusion_matrices.jl:333
# 0.893

# %% [markdown]
# # Decision Trees
#
# ## Model

# %%
dt_model = dtc(merge_purity_threshold=0.9)
dt_mach = machine(dt_model, X, y)
# Out:
# untrained Machine; caches model-specific representations of data
#   model: DecisionTreeClassifier(max_depth = -1, …)
#   args:
#     1:	Source @238 ⏎ Table{AbstractVector{Continuous}}
#     2:	Source @296 ⏎ AbstractVector{Multiclass{3}}

# %%
fit!(dt_mach, rows=train);
# Out:
# [ Info: Training machine(DecisionTreeClassifier(max_depth = -1, …), …).

# %% [markdown]
# ## Visualisation

# %%
fitted_params(dt_mach).tree
# Out:
# Petal_Width < 0.75
# ├─ setosa (38/38)
# └─ Petal_Width < 1.7
#    ├─ Petal_Length < 4.95
#    │  ├─ versicolor (32/32)
#    │  └─ Petal_Width < 1.55
#    │     ├─ virginica (2/2)
#    │     └─ versicolor (1/1)
#    └─ virginica (32/32)

# %%
dt_mach |> feature_importances |> DataFrame
# Out:
# 1×4 DataFrame
#  Row │ Petal_Width  Petal_Length  Sepal_Length  Sepal_Width
#      │ Float64      Float64       Float64       Float64
# ─────┼──────────────────────────────────────────────────────
#    1 │    0.950011     0.0499893           0.0          0.0

# %% [markdown]
# ## Performance

# %%
dt_ŷ = MLJ.predict(dt_mach, rows=test);
dt_ȳ = predict_mode(dt_mach, rows=test);

# %%
cross_entropy(dt_ŷ, y[test]) |> mean |> r3
# Out:
# 2.403

# %%
misclassification_rate(dt_ȳ, y[test]) |> r3
# Out:
# 0.067

# %%
accuracy(dt_ȳ, y[test]) |> r3
# Out:
# 0.933

# %%
kappa(dt_ȳ, y[test]) |> r3
# Out:
# 0.899

# %% [markdown]
# # Random Forests
#
# ## Model

# %%
rfc = @load RandomForestClassifier pkg=DecisionTree verbosity=0
forest = rfc(
  	n_subfeatures = 2,
  	n_trees = 10,
  	sampling_fraction = 0.5,
  	max_depth = 6
)
forest_mach = machine(forest, X, y)
# Out:
# untrained Machine; caches model-specific representations of data
#   model: RandomForestClassifier(max_depth = 6, …)
#   args:
#     1:	Source @320 ⏎ Table{AbstractVector{Continuous}}
#     2:	Source @837 ⏎ AbstractVector{Multiclass{3}}

# %%
fit!(forest_mach, rows=train);
# Out:
# [ Info: Training machine(RandomForestClassifier(max_depth = 6, …), …).

# %%
fitted_params(forest_mach)
# Out:
# (forest = Ensemble of Decision Trees
# Trees:      10
# Avg Leaves: 4.7
# Avg Depth:  3.5,)

# %%
forest_mach |> feature_importances |> DataFrame
# Out:
# 1×4 DataFrame
#  Row │ Petal_Length  Petal_Width  Sepal_Length  Sepal_Width
#      │ Float64       Float64      Float64       Float64
# ─────┼──────────────────────────────────────────────────────
#    1 │     0.488797     0.426361     0.0702893    0.0145528

# %% [markdown]
# ## Performance

# %%
forest_ŷ = MLJ.predict(forest_mach, rows=test);
forest_ȳ = predict_mode(forest_mach, rows=test);

# %%
cross_entropy(forest_ŷ, y[test]) |> mean |> r3
# Out:
# 0.169

# %%
misclassification_rate(forest_ȳ, y[test]) |> r3
# Out:
# 0.111

# %%
accuracy(forest_ȳ, y[test]) |> r3
# Out:
# 0.889

# %%
kappa(forest_ȳ, y[test]) |> r3
# Out:
# 0.831

# %% [markdown]
# # Linear Discriminant Analysis
#
# ## Model

# %%
using MLJMultivariateStatsInterface

# %%
LDA = @load LDA pkg=MultivariateStats verbosity=0
lda_model = LDA()
lda_mach = machine(lda_model, X, y)
# Out:
# untrained Machine; caches model-specific representations of data
#   model: LDA(method = gevd, …)
#   args:
#     1:	Source @073 ⏎ Table{AbstractVector{Continuous}}
#     2:	Source @794 ⏎ AbstractVector{Multiclass{3}}

# %%
fit!(lda_mach, rows=train);
# Out:
# [ Info: Training machine(LDA(method = gevd, …), …).

# %% [markdown]
# ## Visualisation

# %%
lda_x = MLJ.transform(lda_mach)
lda_x |> size
# Out:
# (150, 2)

# %%
lda_x |> head
# Out:
# 5×2 DataFrame
#  Row │ x1         x2
#      │ Float64    Float64
# ─────┼──────────────────────
#    1 │ -0.490621  -0.5954
#    2 │ -0.402083  -0.512882
#    3 │ -0.440995  -0.549617
#    4 │ -0.375092  -0.495139
#    5 │ -0.499025  -0.605012

# %%
lda_df = DataFrame(
	PC1 = lda_x.x1,
	PC2 = lda_x.x2,
	Species = string.(y)
)

lda_df |> head
# Out:
# 5×3 DataFrame
#  Row │ PC1        PC2        Species
#      │ Float64    Float64    String
# ─────┼───────────────────────────────
#    1 │ -0.490621  -0.5954    setosa
#    2 │ -0.402083  -0.512882  setosa
#    3 │ -0.440995  -0.549617  setosa
#    4 │ -0.375092  -0.495139  setosa
#    5 │ -0.499025  -0.605012  setosa

# %%
#| label: fig-fig1
#| fig-cap: "Principal components used to classify the iris data set."
plot(
  lda_df,
  x=:PC1, y=:PC2, color=:Species,
  Geom.point,
  Guide.xlabel("PC1"),
  Guide.ylabel("PC2")
)
# Out:
# Plot(...)

# %% [markdown]
# ## Performance

# %%
lda_ŷ = MLJ.predict(lda_mach, rows=test);
lda_ȳ = predict_mode(lda_mach, rows=test);

# %%
cross_entropy(lda_ŷ, y[test]) |> mean |> r3
# Out:
# 0.639

# %%
misclassification_rate(lda_ȳ, y[test]) |> r3
# Out:
# 0.022

# %%
accuracy(lda_ȳ, y[test]) |> r3
# Out:
# 0.978

# %%
kappa(lda_ȳ, y[test]) |> r3
# Out:
# 0.966
